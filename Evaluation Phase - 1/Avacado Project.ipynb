# %% [markdown]
# # Phase-1 Project-2 Avacado Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 16468
# No of Columns: 14
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# 3  2015.0  Albany
# 4  2015.0  Albany

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %%
df.duplicated().sum()
# Out:
# 14950

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#               Missing Values  % Missing data
# Date                   14951       90.788195
# AveragePrice           14951       90.788195
# Total Volume           14951       90.788195
# 4046                   14951       90.788195
# 4225                   14951       90.788195
# 4770                   14951       90.788195
# Total Bags             14951       90.788195
# Small Bags             14951       90.788195
# Large Bags             14951       90.788195
# XLarge Bags            14951       90.788195
# type                   14951       90.788195
# year                   14951       90.788195
# region                 14951       90.788195

# %% [markdown]
# Datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   float64
#  12  region        1517 non-null   object
# dtypes: float64(10), object(3)
# memory usage: 1.6+ MB

# %%
df['Date']=pd.to_datetime(df.Date)

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# Statistical Matrix

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.describe(),linewidths = 0.1,fmt='0.1f',annot = True,cmap='PiYG')
# Out:
# <AxesSubplot:>

# %%
df.describe().T.round(3)
# Out:
#                count         mean          std       min        25%  \
# AveragePrice  1517.0        1.075        0.189      0.49       0.98
# Total Volume  1517.0  1601879.068  4433142.821  38750.74  147469.99
# 4046          1517.0   646438.654  1947613.570    467.72   20400.34
# 4225          1517.0   611437.503  1672906.165   1783.77   41476.06
# 4770          1517.0    50405.495   137781.249      0.00     911.25
# Total Bags    1517.0   293597.416   757976.531   3311.77   36206.89
# Small Bags    1517.0   248773.595   647476.521   3311.77   29727.22
# Large Bags    1517.0    42642.049   118215.682      0.00     540.74
# XLarge Bags   1517.0     2181.771     7455.712      0.00       0.00
# year          1517.0     2015.163        0.369   2015.00    2015.00
#
#                     50%        75%          max
# AveragePrice       1.08       1.19         1.68
# Total Volume  402791.86  981975.08  44655461.51
# 4046           81751.17  377578.48  18933038.04
# 4225          118664.89  485150.34  18956479.74
# 4770            7688.17   29167.30   1381516.11
# Total Bags     73979.06  157609.68   6736304.04
# Small Bags     62375.69  146199.35   5893641.72
# Large Bags      5044.35   29267.67   1121076.47
# XLarge Bags        0.00     401.48    108072.79
# year            2015.00    2015.00      2016.00

# %% [markdown]
# # Statistical Analysis

# %%
print("\033[1m"+'Minimum Price of Avocado :'+"\033[0m",df.AveragePrice.min(),'USD')
print("\033[1m"+'Maximum Price of avacado :'+"\033[0m",df.AveragePrice.max(),'USD')
print("\033[1m"+'Average Price of avacado :'+"\033[0m",df.AveragePrice.mean(),'USD')
# Out:
# Minimum Price of Avocado : 0.49 USD
# Maximum Price of avacado : 1.68 USD
# Average Price of avacado : 1.0749901120632825 USD

# %% [markdown]
# Avacado varies from 0.44 USD To 3.25 USD with average price of 1.40 USD per unit

# %%
plt.figure(figsize=(12,7))
plt.title('Distribution Price')
sns.distplot(df["AveragePrice"], color='b')
# Out:
# <AxesSubplot:title={'center':'Distribution Price'}, xlabel='AveragePrice', ylabel='Density'>

# %%
df['type'].value_counts()
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
df.groupby('type')['AveragePrice'].mean()
# Out:
# type
# conventional    1.07499
# Name: AveragePrice, dtype: float64

# %%
print("\033[1m"+'Percentage difference in price of avacado :'+"\033[0m",((1.65399-1.1580)/1.1580)*100,"%")
# Out:
# Percentage difference in price of avacado : 42.831606217616596 %

# %%
plt.figure(figsize=(8,6))
sns.boxplot(y="type", x="AveragePrice", data=df, palette = 'hsv')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='type'>

# %%
df.groupby('type')['Total Volume'].mean()
# Out:
# type
# conventional    1.601879e+06
# Name: Total Volume, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='year', y='Total Volume', hue='type',data=df, palette='coolwarm',ci=68)
plt.show()

# %% [markdown]
# # The Average price varies over year and season

# %%
pd.crosstab([df.type,df.year],df.AveragePrice, margins= True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_c26e8_row0_col0, #T_c26e8_row0_col1, #T_c26e8_row0_col2, #T_c26e8_row0_col3, #T_c26e8_row0_col4, #T_c26e8_row0_col5, #T_c26e8_row0_col6, #T_c26e8_row0_col8, #T_c26e8_row0_col10, #T_c26e8_row0_col12, #T_c26e8_row0_col14, #T_c26e8_row0_col16, #T_c26e8_row0_col17, #T_c26e8_row0_col19, #T_c26e8_row0_col20, #T_c26e8_row0_col26, #T_c26e8_row0_col48, #T_c26e8_row0_col64, #T_c26e8_row0_col90, #T_c26e8_row1_col94, #T_c26e8_row1_col95, #T_c26e8_row1_col96, #T_c26e8_row1_col97, #T_c26e8_row1_col98, #T_c26e8_row1_col99, #T_c26e8_row1_col100, #T_c26e8_row1_col101, #T_c26e8_row1_col102, #T_c26e8_row1_col103, #T_c26e8_row1_col104, #T_c26e8_row1_col105, #T_c26e8_row1_col106, #T_c26e8_row1_col107, #T_c26e8_row1_col108, #T_c26e8_row1_col109, #T_c26e8_row1_col110, #T_c26e8_row1_col111, #T_c26e8_row1_col112, #T_c26e8_row2_col0, #T_c26e8_row2_col1, #T_c26e8_row2_col2, #T_c26e8_row2_col3, #T_c26e8_row2_col4, #T_c26e8_row2_col5, #T_c26e8_row2_col6, #T_c26e8_row2_col7, #T_c26e8_row2_col8, #T_c26e8_row2_col9, #T_c26e8_row2_col10, #T_c26e8_row2_col11, #T_c26e8_row2_col12, #T_c26e8_row2_col13, #T_c26e8_row2_col14, #T_c26e8_row2_col15, #T_c26e8_row2_col16, #T_c26e8_row2_col17, #T_c26e8_row2_col18, #T_c26e8_row2_col19, #T_c26e8_row2_col20, #T_c26e8_row2_col21, #T_c26e8_row2_col22, #T_c26e8_row2_col23, #T_c26e8_row2_col24, #T_c26e8_row2_col25, #T_c26e8_row2_col26, #T_c26e8_row2_col27, #T_c26e8_row2_col28, #T_c26e8_row2_col29, #T_c26e8_row2_col30, #T_c26e8_row2_col31, #T_c26e8_row2_col32, #T_c26e8_row2_col33, #T_c26e8_row2_col34, #T_c26e8_row2_col35, #T_c26e8_row2_col36, #T_c26e8_row2_col37, #T_c26e8_row2_col38, #T_c26e8_row2_col39, #T_c26e8_row2_col40, #T_c26e8_row2_col41, #T_c26e8_row2_col42, #T_c26e8_row2_col43, #T_c26e8_row2_col44, #T_c26e8_row2_col45, #T_c26e8_row2_col46, #T_c26e8_row2_col47, #T_c26e8_row2_col48, #T_c26e8_row2_col49, #T_c26e8_row2_col50, #T_c26e8_row2_col51, #T_c26e8_row2_col52, #T_c26e8_row2_col53, #T_c26e8_row2_col54, #T_c26e8_row2_col55, #T_c26e8_row2_col56, #T_c26e8_row2_col57, #T_c26e8_row2_col58, #T_c26e8_row2_col59, #T_c26e8_row2_col60, #T_c26e8_row2_col61, #T_c26e8_row2_col62, #T_c26e8_row2_col63, #T_c26e8_row2_col64, #T_c26e8_row2_col65, #T_c26e8_row2_col66, #T_c26e8_row2_col67, #T_c26e8_row2_col68, #T_c26e8_row2_col69, #T_c26e8_row2_col70, #T_c26e8_row2_col71, #T_c26e8_row2_col72, #T_c26e8_row2_col73, #T_c26e8_row2_col74, #T_c26e8_row2_col75, #T_c26e8_row2_col76, #T_c26e8_row2_col77, #T_c26e8_row2_col78, #T_c26e8_row2_col79, #T_c26e8_row2_col80, #T_c26e8_row2_col81, #T_c26e8_row2_col82, #T_c26e8_row2_col83, #T_c26e8_row2_col84, #T_c26e8_row2_col85, #T_c26e8_row2_col86, #T_c26e8_row2_col87, #T_c26e8_row2_col88, #T_c26e8_row2_col89, #T_c26e8_row2_col90, #T_c26e8_row2_col91, #T_c26e8_row2_col92, #T_c26e8_row2_col93, #T_c26e8_row2_col94, #T_c26e8_row2_col95, #T_c26e8_row2_col96, #T_c26e8_row2_col97, #T_c26e8_row2_col98, #T_c26e8_row2_col99, #T_c26e8_row2_col100, #T_c26e8_row2_col101, #T_c26e8_row2_col102, #T_c26e8_row2_col103, #T_c26e8_row2_col104, #T_c26e8_row2_col105, #T_c26e8_row2_col106, #T_c26e8_row2_col107, #T_c26e8_row2_col108, #T_c26e8_row2_col109, #T_c26e8_row2_col110, #T_c26e8_row2_col111, #T_c26e8_row2_col112, #T_c26e8_row2_col113 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col7, #T_c26e8_row0_col9, #T_c26e8_row0_col34, #T_c26e8_row0_col77, #T_c26e8_row0_col92 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_c26e8_row0_col11, #T_c26e8_row0_col13, #T_c26e8_row0_col38, #T_c26e8_row0_col79, #T_c26e8_row0_col87, #T_c26e8_row0_col89, #T_c26e8_row0_col94, #T_c26e8_row0_col95, #T_c26e8_row0_col96, #T_c26e8_row0_col97, #T_c26e8_row0_col98, #T_c26e8_row0_col99, #T_c26e8_row0_col100, #T_c26e8_row0_col101, #T_c26e8_row0_col102, #T_c26e8_row0_col103, #T_c26e8_row0_col104, #T_c26e8_row0_col105, #T_c26e8_row0_col106, #T_c26e8_row0_col107, #T_c26e8_row0_col108, #T_c26e8_row0_col109, #T_c26e8_row0_col110, #T_c26e8_row0_col111, #T_c26e8_row0_col112, #T_c26e8_row1_col0, #T_c26e8_row1_col1, #T_c26e8_row1_col2, #T_c26e8_row1_col3, #T_c26e8_row1_col4, #T_c26e8_row1_col5, #T_c26e8_row1_col6, #T_c26e8_row1_col7, #T_c26e8_row1_col8, #T_c26e8_row1_col9, #T_c26e8_row1_col10, #T_c26e8_row1_col11, #T_c26e8_row1_col12, #T_c26e8_row1_col13, #T_c26e8_row1_col14, #T_c26e8_row1_col15, #T_c26e8_row1_col16, #T_c26e8_row1_col17, #T_c26e8_row1_col18, #T_c26e8_row1_col19, #T_c26e8_row1_col20, #T_c26e8_row1_col21, #T_c26e8_row1_col22, #T_c26e8_row1_col23, #T_c26e8_row1_col24, #T_c26e8_row1_col25, #T_c26e8_row1_col26, #T_c26e8_row1_col27, #T_c26e8_row1_col28, #T_c26e8_row1_col29, #T_c26e8_row1_col30, #T_c26e8_row1_col31, #T_c26e8_row1_col32, #T_c26e8_row1_col33, #T_c26e8_row1_col34, #T_c26e8_row1_col35, #T_c26e8_row1_col36, #T_c26e8_row1_col37, #T_c26e8_row1_col38, #T_c26e8_row1_col39, #T_c26e8_row1_col40, #T_c26e8_row1_col41, #T_c26e8_row1_col42, #T_c26e8_row1_col43, #T_c26e8_row1_col44, #T_c26e8_row1_col45, #T_c26e8_row1_col46, #T_c26e8_row1_col47, #T_c26e8_row1_col48, #T_c26e8_row1_col49, #T_c26e8_row1_col50, #T_c26e8_row1_col51, #T_c26e8_row1_col52, #T_c26e8_row1_col53, #T_c26e8_row1_col54, #T_c26e8_row1_col55, #T_c26e8_row1_col56, #T_c26e8_row1_col57, #T_c26e8_row1_col58, #T_c26e8_row1_col59, #T_c26e8_row1_col60, #T_c26e8_row1_col61, #T_c26e8_row1_col62, #T_c26e8_row1_col63, #T_c26e8_row1_col64, #T_c26e8_row1_col65, #T_c26e8_row1_col66, #T_c26e8_row1_col67, #T_c26e8_row1_col68, #T_c26e8_row1_col69, #T_c26e8_row1_col70, #T_c26e8_row1_col71, #T_c26e8_row1_col72, #T_c26e8_row1_col73, #T_c26e8_row1_col74, #T_c26e8_row1_col75, #T_c26e8_row1_col76, #T_c26e8_row1_col77, #T_c26e8_row1_col78, #T_c26e8_row1_col79, #T_c26e8_row1_col80, #T_c26e8_row1_col81, #T_c26e8_row1_col82, #T_c26e8_row1_col83, #T_c26e8_row1_col84, #T_c26e8_row1_col85, #T_c26e8_row1_col86, #T_c26e8_row1_col88, #T_c26e8_row1_col90, #T_c26e8_row1_col91, #T_c26e8_row1_col92, #T_c26e8_row1_col93, #T_c26e8_row1_col113 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_c26e8_row0_col15, #T_c26e8_row0_col27, #T_c26e8_row0_col76, #T_c26e8_row0_col83 {
#   background-color: #2a9466;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col18, #T_c26e8_row0_col24, #T_c26e8_row0_col69 {
#   background-color: #249266;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col21, #T_c26e8_row0_col29, #T_c26e8_row0_col32, #T_c26e8_row0_col80, #T_c26e8_row1_col89 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col22, #T_c26e8_row0_col28 {
#   background-color: #198c66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col23, #T_c26e8_row0_col33 {
#   background-color: #1f8f66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col25 {
#   background-color: #3f9f66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col30, #T_c26e8_row0_col82 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_c26e8_row0_col31, #T_c26e8_row0_col46 {
#   background-color: #279366;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col35, #T_c26e8_row0_col41, #T_c26e8_row0_col91 {
#   background-color: #339966;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col36, #T_c26e8_row0_col85 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col37 {
#   background-color: #6ab466;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col39 {
#   background-color: #389c66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col40, #T_c26e8_row0_col84 {
#   background-color: #2e9666;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col42 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_c26e8_row0_col43, #T_c26e8_row0_col45, #T_c26e8_row0_col68 {
#   background-color: #1c8e66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col44 {
#   background-color: #0b8566;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col47, #T_c26e8_row0_col50, #T_c26e8_row0_col54, #T_c26e8_row0_col75 {
#   background-color: #128866;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col49 {
#   background-color: #259266;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col51, #T_c26e8_row0_col61 {
#   background-color: #289366;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col52 {
#   background-color: #158a66;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col53, #T_c26e8_row0_col74 {
#   background-color: #2d9666;
#   color: #f1f1f1;
# }
# #T_c26e8_row0_col55 {
#   background-color: #17

# %%
df.groupby(['year','type'])['AveragePrice'].agg([min,max,np.mean,np.median])
# Out:
#                       min   max      mean  median
# year   type
# 2015.0 conventional  0.49  1.45  1.060110    1.07
# 2016.0 conventional  0.58  1.68  1.151498    1.12

# %%
df.groupby(['year','type'])['Total Volume','Total Bags','Small Bags','Large Bags','XLarge Bags'].agg([sum])
# Out:
#                      Total Volume    Total Bags    Small Bags   Large Bags  \
#                               sum           sum           sum          sum
# year   type
# 2015.0 conventional  2.044783e+09  3.346280e+08  2.773770e+08  55391693.84
# 2016.0 conventional  3.852675e+08  1.107592e+08  1.000126e+08   9296295.06
#
#                     XLarge Bags
#                             sum
# year   type
# 2015.0 conventional  1859398.48
# 2016.0 conventional  1450348.24

# %%
df.sort_values(by=['Date'], inplace=True, ascending=True)

# %%
mask = df['type']== 'conventional'
plt.rc('figure', titlesize=20)
fig = plt.figure(figsize = (27, 12))
fig.suptitle('Average Price of Conventional Avocados Over Time', fontsize=25)
ax = fig.add_subplot(111)

dates = df[mask]['Date'].tolist()
avgPrices = df[mask]['AveragePrice'].tolist()

plt.scatter( dates,avgPrices, c=avgPrices, cmap='plasma')
ax.set_xlabel('Date',fontsize = 15,)
ax.set_ylabel('Average Price (USD)', fontsize = 15)
ax.set_xlim()
ax.tick_params(labelrotation=90)

plt.show()

# %%
mask = df['type']== 'organic'
plt.rc('figure', titlesize=20)
fig = plt.figure(figsize = (27, 12))
fig.suptitle('Average Price of Organic Avocados Over Time', fontsize=25)
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.93)

dates = df[mask]['Date'].tolist()
avgPrices = df[mask]['AveragePrice'].tolist()

plt.scatter(dates,avgPrices, c=avgPrices, cmap='plasma')
ax.set_xlabel('Date',fontsize = 15)
ax.set_ylabel('Average Price (USD)', fontsize = 15)
plt.xlim()
plt.show()

# %%
df.groupby(['region'])['Total Volume','AveragePrice'].agg([sum])
# Out:
#                      Total Volume AveragePrice
#                               sum          sum
# region
# Albany               5.111443e+06        82.99
# Atlanta              2.525241e+07        54.65
# BaltimoreWashington  5.249687e+07        75.46
# Boise                5.268001e+06        63.37
# Boston               3.431443e+07        74.74
# BuffaloRochester     6.741403e+06        66.38
# California           4.586810e+08        80.25
# Charlotte            5.464623e+06        40.66
# Chicago              1.867329e+07        27.94
# Columbus             6.850740e+06        47.59
# DallasFtWorth        2.032117e+07        12.85
# Denver               1.722244e+07        25.94
# Detroit              1.356261e+07        41.65
# GrandRapids          4.390393e+06        26.15
# GreatLakes           5.897445e+07        19.93
# HarrisburgScranton   4.148077e+06        21.99
# HartfordSpringfield  3.491504e+06        15.72
# Houston              3.235137e+07        22.64
# Indianapolis         2.520069e+06        18.02
# Jacksonville         5.658909e+06        45.66
# LasVegas             2.790102e+06        10.41
# LosAngeles           8.196539e+06         2.59
# Louisville           2.639857e+06        35.46
# MiamiFtLauderdale    8.012470e+06        20.00
# Midsouth             4.239178e+07        19.46
# Nashville            4.186786e+06        25.71
# NewYork              5.997083e+07        54.94
# Northeast            4.159036e+07        14.84
# NorthernNewEngland   1.148272e+07        32.22
# Orlando              6.328122e+06        23.80
# Philadelphia         5.003988e+06        16.82
# PhoenixTucson        5.661233e+07        34.31
# Pittsburgh           1.791478e+06        25.93
# Plains               2.007570e+07        12.62
# Portland             1.485553e+07        31.31
# RaleighGreensboro    3.848596e+06        18.66
# RichmondNorfolk      4.131917e+06        21.10
# Roanoke              2.225069e+06        18.64
# SanDiego             1.905142e+07        37.75
# SanFrancisco         1.275176e+07        17.26
# Seattle              4.405780e+06         9.47
# SouthCarolina        8.010844e+06        25.71
# SouthCentral         2.143828e+08        31.93
# Southeast            2.749715e+07         9.82
# Spokane              3.782042e+06        53.71
# StLouis              3.111993e+06        20.16
# Syracuse             9.229898e+05        25.60
# Tampa                1.115006e+07        36.34
# TotalUS              8.234286e+08        25.29
# West                 2.006978e+08        33.87
# WestTexNewMexico     2.322790e+07        20.45

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#            Date  AveragePrice  Total Volume       4046       4225      4770  \
# 1265 2015-01-02          0.71     916367.42  611270.39  205181.23  14107.36
# 1111 2015-01-02          0.97     135656.36   35897.25   84741.31   2704.69
# 1011 2015-01-02          0.91     469684.32  284674.20   78055.21  27248.16
# 488  2015-01-02          0.92     245352.56    7245.61  181784.28  14761.53
# 755  2015-01-02          1.14     569304.80   30263.22  417993.89   1722.10
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 1265    85808.44    82065.70     3742.74          0.0  conventional  2015.0
# 1111    12313.11    12276.59       36.52          0.0  conventional  2015.0
# 1011    79706.75    51793.30    27913.45          0.0  conventional  2015.0
# 488     41561.14    20669.59    18130.75       2760.8  conventional  2015.0
# 755    119325.59   104365.66    14959.93          0.0  conventional  2015.0
#
#                 region
# 1265  WestTexNewMexico
# 1111           Spokane
# 1011     SouthCarolina
# 488       Indianapolis
# 755       Philadelphia

# %%
df2=df.copy()

# %%
df2.drop(['Date','type','region','year'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,25), facecolor='white')
plotnumber =1
for column in df2:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.distplot(df2[column], color='r',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
sns.set_palette('gist_rainbow_r')
plt.figure(figsize=(20,20), facecolor='white')
plotnumber =1
for column in df2:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.violinplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %% [markdown]
# Avacado availability and price also vary over the year according to seasonal changes.Lets check the variation Avg price and sales volume over each month.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/avocado.csv')

# %%
df3=df.copy()

# %%
df3['Year'], df3['Month'], df3['Day'] = df3['Date'].str.split('-').str
df3.drop(columns=['Date','year'], inplace=True)
df3
# Out:
#        Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0             0.0          1.33      64236.62  1036.74   54454.85   48.16
# 1             1.0          1.35      54876.98   674.28   44638.81   58.33
# 2             2.0          0.93     118220.22   794.70  109149.67  130.50
# 3             3.0          1.08      78992.15  1132.00   71976.41   72.58
# 4             4.0          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16463         NaN           NaN           NaN      NaN        NaN     NaN
# 16464         NaN           NaN           NaN      NaN        NaN     NaN
# 16465         NaN           NaN           NaN      NaN        NaN     NaN
# 16466         NaN           NaN           NaN      NaN        NaN     NaN
# 16467         NaN           NaN           NaN      NaN        NaN     NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags          type  region  \
# 0         8696.87     8603.62       93.25          0.0  conventional  Albany
# 1         9505.56     9408.07       97.49          0.0  conventional  Albany
# 2         8145.35     8042.21      103.14          0.0  conventional  Albany
# 3         5811.16     5677.40      133.76          0.0  conventional  Albany
# 4         6183.95     5986.26      197.69          0.0  conventional  Albany
# ...           ...         ...         ...          ...           ...     ...
# 16463         NaN         NaN         NaN          NaN           NaN     NaN
# 16464         NaN         NaN         NaN          NaN           NaN     NaN
# 16465         NaN         NaN         NaN          NaN           NaN     NaN
# 16466         NaN         NaN         NaN          NaN           NaN     NaN
# 16467         NaN         NaN         NaN          NaN           NaN     NaN
#
#       Year Month   Day
# 0       27    12  2015
# 1       20    12  2015
# 2       13    12  2015
# 3       06    12  2015
# 4       29    11  2015
# ...    ...   ...   ...
# 16463  NaN   NaN   NaN
# 16464  NaN   NaN   NaN
# 16465  NaN   NaN   NaN
# 16466  NaN   NaN   NaN
# 16467  NaN   NaN   NaN
#
# [16468 rows x 15 columns]

# %%
df3.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0         0.0          1.33      64236.62  1036.74   54454.85   48.16
# 1         1.0          1.35      54876.98   674.28   44638.81   58.33
# 2         2.0          0.93     118220.22   794.70  109149.67  130.50
# 3         3.0          1.08      78992.15  1132.00   71976.41   72.58
# 4         4.0          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  region Year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  Albany   27
# 1     9505.56     9408.07       97.49          0.0  conventional  Albany   20
# 2     8145.35     8042.21      103.14          0.0  conventional  Albany   13
# 3     5811.16     5677.40      133.76          0.0  conventional  Albany   06
# 4     6183.95     5986.26      197.69          0.0  conventional  Albany   29
#
#   Month
# 0    12
# 1    12
# 2    12
# 3    12
# 4    11

# %%
df3['Year'].value_counts()
# Out:
# 22    88
# 15    86
# 08    85
# 01    82
# 05    61
# 12    59
# 29    58
# 19    56
# 26    55
# 13    53
# 06    53
# 20    53
# 27    52
# 25    52
# 18    51
# 04    47
# 11    47
# 10    46
# 03    45
# 17    43
# 24    42
# 07    38
# 31    37
# 14    36
# 21    35
# 28    33
# 09    26
# 02    25
# 16    25
# 23    24
# 30    24
# Name: Year, dtype: int64

# %%
sns.countplot('Year',data=df3)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Month', data=df3, palette="spring")
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %%
df3['Month'].value_counts().max()
# Out:
# 179

# %%
df3['Month'].value_counts().min()
# Out:
# 90

# %% [markdown]
# # Checking Month-Wise Variation in Average Price

# %%
plt.figure(figsize=(15,7))
sns.barplot(x="Month", y="AveragePrice", hue='type', data=df3)
plt.show()

# %%
df3.groupby(['Month','type'])['AveragePrice'].agg([np.mean]).T
# Out:
# Month           01           02           03           04           05  \
# type  conventional conventional conventional conventional conventional
# mean      1.073868     1.042424     1.083855     1.072038     1.037011
#
# Month           06           07           08           09           10  \
# type  conventional conventional conventional conventional conventional
# mean      1.042966     1.101111     1.110169     1.061556       1.1051
#
# Month           11           12
# type  conventional conventional
# mean      1.118571     1.069099

# %%
plt.figure(figsize=(10,10))
sns.catplot(x = "Month", y = "AveragePrice", kind ='violin', data=df3, linewidth=2)
plt.show()

# %% [markdown]
# # explore region feature

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['region'],y=df['AveragePrice'], data=df3)
plt.title(f'Bar Plot for regions')
plt.xticks(rotation=90)
plt.show()

# %%
region = df.groupby('region')['Total Volume'].sum().sort_values(ascending=False).reset_index()
plt.figure(figsize=(15,13))
sns.barplot(x=region["Total Volume"], y=region["region"], data=df, palette="Set1")
plt.show()

# %%
df.groupby(['region'])['Total Volume','Total Bags','Small Bags','Large Bags','XLarge Bags'].agg([np.mean])
# Out:
#                      Total Volume    Total Bags    Small Bags     Large Bags  \
#                              mean          mean          mean           mean
# region
# Albany               7.629020e+04  1.216629e+04  1.181550e+04     347.246866
# Atlanta              4.676372e+05  8.621736e+04  4.740999e+04   38747.062407
# BaltimoreWashington  8.076442e+05  1.846829e+05  1.801890e+05    4221.447231
# Boise                8.104617e+04  2.605436e+04  2.526996e+04     748.342154
# Boston               5.534586e+05  1.223562e+05  1.210160e+05     764.848710
# BuffaloRochester     1.321844e+05  6.661483e+04  6.554765e+04     384.352549
# California           6.035277e+06  1.415122e+06  1.286774e+06  109555.190526
# Charlotte            1.762782e+05  5.798790e+04  5.270983e+04    5230.527742
# Chicago              8.118822e+05  9.829844e+04  9.470367e+04    3061.164348
# Columbus             1.457604e+05  2.463157e+04  1.866047e+04    4032.940000
# DallasFtWorth        1.195363e+06  9.916713e+04  8.670487e+04   12334.903529
# Denver               7.176015e+05  1.111024e+05  6.087965e+04   50135.161250
# Detroit              3.390654e+05  7.253078e+04  6.163519e+04    1557.678250
# GrandRapids          1.908866e+05  6.434865e+04  5.934261e+04    4124.442609
# GreatLakes           3.276358e+06  6.902264e+05  5.701240e+05  103211.250556
# HarrisburgScranton   2.183198e+05  7.099577e+04  6.922653e+04    1763.903684
# HartfordSpringfield  2.685772e+05  4.423218e+04  4.176598e+04    2466.196154
# Houston              1.115564e+06  1.236014e+05  7.662979e+04   46965.139655
# Indianapolis         1.575043e+05  4.042118e+04  2.515139e+04   14170.896250
# Jacksonville         1.380222e+05  3.337124e+04  1.881092e+04   14555.283171
# LasVegas             2.790102e+05  3.678120e+04  3.627888e+04     502.317000
# LosAngeles           2.732180e+06  2.656486e+05  2.331338e+05   29588.213333
# Louisville           7.764284e+04  2.334985e+04  1.176304e+04   10777.824118
# MiamiFtLauderdale    4.713218e+05  8.315592e+04  4.558801e+04   37518.889412
# Midsouth             2.355099e+06  5.009069e+05  4.444993e+05   54315.115000
# Nashville            1.674714e+05  3.087883e+04  2.515520e+04    5552.626400
# NewYork              1.362973e+06  2.883272e+05  2.329357e+05   55324.481818
# Northeast            3.465864e+06  9.233073e+05  8.325909e+05   90716.120000
# NorthernNewEngland   3.959559e+05  6.571578e+04  6.551439e+04     201.392414
# Orlando              3.013391e+05  6.363694e+04  3.614822e+04   27443.767619
# Philadelphia         3.849221e+05  1.094200e+05  9.617036e+04   13249.433846
# PhoenixTucson        1.088699e+06  9.167066e+04  7.375194e+04   17906.916538
# Pittsburgh           8.143082e+04  2.559071e+04  1.647854e+04    9094.720455
# Plains               1.672975e+06  2.444021e+05  2.414715e+05    1871.381667
# Portland             4.951845e+05  1.285817e+05  1.268568e+05    1146.124667
# RaleighGreensboro    2.405372e+05  6.992312e+04  6.351872e+04    6404.406250
# RichmondNorfolk      1.967580e+05  3.463287e+04  3.431110e+04     318.440476
# Roanoke              1.308864e+05  3.082652e+04  2.999228e+04     834.067647
# SanDiego             5.013533e+05  5.612442e+04  4.789166e+04    8229.355789
# SanFrancisco         8.501176e+05  8.473144e+04  8.385832e+04     805.786667
# Seattle              4.895311e+05  1.965804e+05  1.963348e+05       8.243333
# SouthCarolina        3.337852e+05  7.202420e+04  6.069505e+04   11328.591250
# SouthCentral         5.496995e+06  6.837558e+05  5.549597e+05  123663.470256
# Southeast            3.055239e+06  5.529500e+05  3.165600e+05  236389.612222
# Spokane              7.718453e+04  1.343052e+04  1.333777e+04      89.895102
# StLouis              1.944995e+05  4.718668e+04  4.715167e+04      34.738750
# Syracuse             4.857841e+04  2.274572e+04  2.257527e+04     170.450000
# Tampa                3.279430e+05  9.260880e+04  5.815579e+04   34442.363529
# TotalUS              3.293714e+07  5.322368e+06  4.519090e+06  779546.107600
# West                 5.574939e+06  1.061338e+06  7.447474e+05  315172.970278
# WestTexNewMexico     8.602926e+05  1.074539e+05  9.298900e+04   14464.946667
#
#                       XLarge Bags
#                              mean
# region
# Albany                   3.547164
# Atlanta                 60.306481
# BaltimoreWashington    272.483077
# Boise                   36.056308
# Boston                 575.326935
# BuffaloRochester       682.826667
# California           18792.960132
# Charlotte               47.535806
# Chicago                533.601304
# Columbus              1938.165745
# DallasFtWorth          127.362353
# Denver                  87.601250
# Detroit               9337.904250
# GrandRapids            881.601304
# GreatLakes           16891.117778
# HarrisburgScranton       5.336316
# HartfordSpringfield      0.000000
# Houston                  6.513448
# Indianapolis          1098.895000
# Jacksonville             5.035122
# LasVegas                 0.000000
# LosAngeles            2926.593333
# Louisville             808.985588
# MiamiFtLauderdale       49.019412
# Midsouth              2092.557222
# Nashville              171.002000
# NewYork                 67.019773
# Northeast                0.272500
# NorthernNewEngland       0.000000
# Orlando                 44.958095
# Philadelphia             0.231538
# PhoenixTucson           11.805385
# Pittsburgh              17.445455
# Plains                1059.265833
# Portland               578.789000
# RaleighGreensboro        0.000000
# RichmondNorfolk          3.327619
# Roanoke                  0.176471
# SanDiego                 3.403421
# SanFrancisco            67.334667
# Seattle                237.385556
# SouthCarolina            0.557083
# SouthCentral          5132.639487
# Southeast                0.331111
# Spokane                  2.851429
# StLouis                  0.265625
# Syracuse                 0.000000
# Tampa                   10.640882
# TotalUS              23732.280400
# West                  1417.661111
# WestTexNewMexico         0.000000

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
y = df[['4046','4225','4770']]
X = df['year']
for col in y:
    if plotnumber<=9:
        plt.subplot(3,3,plotnumber)
        sns.barplot(X,y[col])
        plt.xlabel('Year',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Production of PLU 4046 has grown over the 4 years and is greater than the production of PLU 4225 and PLU 4770, which is least produced.

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
y = df[['Small Bags','Large Bags','XLarge Bags']]
X = df['year']
for col in y:
    if plotnumber<=9:
        plt.subplot(3,3,plotnumber)
        sns.barplot(X,y[col])
        plt.xlabel('Year',fontsize=20)
        plt.ylabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %%
mask = df['type']=='conventional'
g = sns.factorplot('AveragePrice','region',data=df[mask],
                   hue='year',
                   size=13,
                   aspect=0.8,
                   palette='magma',
                   join=False,
              )

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(df2)

# %% [markdown]
# # Encoding categorical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df3['region']=le.fit_transform(df3['region'])
df3['type']=le.fit_transform(df3['type'])
df3.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0         0.0          1.33      64236.62  1036.74   54454.85   48.16
# 1         1.0          1.35      54876.98   674.28   44638.81   58.33
# 2         2.0          0.93     118220.22   794.70  109149.67  130.50
# 3         3.0          1.08      78992.15  1132.00   71976.41   72.58
# 4         4.0          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  region Year Month  \
# 0     8696.87     8603.62       93.25          0.0     0       0   27    12
# 1     9505.56     9408.07       97.49          0.0     0       0   20    12
# 2     8145.35     8042.21      103.14          0.0     0       0   13    12
# 3     5811.16     5677.40      133.76          0.0     0       0   06    12
# 4     6183.95     5986.26      197.69          0.0     0       0   29    11
#
#     Day
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %% [markdown]
# # Outliers Detection and Removal

# %%
plt.figure(figsize=(18,15), facecolor='white')
plotnumber =1
for column in df2:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(df2[column], palette='hsv')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
print("\033[1m"+'Shape of dataset after removing outliers :'+"\033[0m",df3.shape)
# Out:
# Shape of dataset after removing outliers : (16468, 15)

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((18249-17651)/18249)*100,'%')
# Out:
# Percentage Data Loss : 3.276891884486821 %

# %% [markdown]
# # Corrleation

# %%
df3.corr()
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice   -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total Volume    0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046            0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225            0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770            0.075647     -0.100567      0.934347  0.898570  0.927757
# Total Bags      0.081007     -0.111597      0.967689  0.930395  0.951779
# Small Bags      0.083485     -0.097682      0.960642  0.922278  0.943988
# Large Bags      0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge Bags    -0.050993     -0.048284      0.521717  0.474063  0.504718
# type                 NaN           NaN           NaN       NaN       NaN
# region          0.012123     -0.229408      0.236579  0.269481  0.215733
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Unnamed: 0    0.075647    0.081007    0.083485    0.065364    -0.050993
# AveragePrice -0.100567   -0.111597   -0.097682   -0.177480    -0.048284
# Total Volume  0.934347    0.967689    0.960642    0.910226     0.521717
# 4046          0.898570    0.930395    0.922278    0.884229     0.474063
# 4225          0.927757    0.951779    0.943988    0.900496     0.504718
# 4770          1.000000    0.926405    0.923607    0.840523     0.646053
# Total Bags    0.926405    1.000000    0.997341    0.911336     0.601856
# Small Bags    0.923607    0.997341    1.000000    0.879131     0.611300
# Large Bags    0.840523    0.911336    0.879131    1.000000     0.447779
# XLarge Bags   0.646053    0.601856    0.611300    0.447779     1.000000
# type               NaN         NaN         NaN         NaN          NaN
# region        0.138092    0.190001    0.168650    0.297452    -0.046144
#
#                   type    region
# Unnamed: 0         NaN  0.012123
# AveragePrice       NaN -0.229408
# Total Volume       NaN  0.236579
# 4046               NaN  0.269481
# 4225               NaN  0.215733
# 4770               NaN  0.138092
# Total Bags         NaN  0.190001
# Small Bags         NaN  0.168650
# Large Bags         NaN  0.297452
# XLarge Bags        NaN -0.046144
# type          1.000000  0.869561
# region        0.869561  1.000000

# %%
plt.figure(figsize=(25,18))
sns.heatmap(df3.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="gist_stern")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
plt.figure(figsize = (18,6))
df3.corr()['AveragePrice'].drop(['AveragePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('AveragePrice',fontsize=15)
plt.title('Correlation of features with Target Variable Average Price',fontsize = 18)
plt.show()

# %%
df3.head()
# Out:
#    Unnamed: 0  AveragePrice  Total Volume     4046       4225    4770  \
# 0         0.0          1.33      64236.62  1036.74   54454.85   48.16
# 1         1.0          1.35      54876.98   674.28   44638.81   58.33
# 2         2.0          0.93     118220.22   794.70  109149.67  130.50
# 3         3.0          1.08      78992.15  1132.00   71976.41   72.58
# 4         4.0          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  region Year Month  \
# 0     8696.87     8603.62       93.25          0.0     0       0   27    12
# 1     9505.56     9408.07       97.49          0.0     0       0   20    12
# 2     8145.35     8042.21      103.14          0.0     0       0   13    12
# 3     5811.16     5677.40      133.76          0.0     0       0   06    12
# 4     6183.95     5986.26      197.69          0.0     0       0   29    11
#
#     Day
# 0  2015
# 1  2015
# 2  2015
# 3  2015
# 4  2015

# %%
df3.drop(columns=['4046','4225','4770','region','Total Bags'],axis=1, inplace=True)

# %% [markdown]
# Checking Multicollinearity between features using variance_inflation_factor

# %%
plt.figure(figsize = (14,5))
df3.corr()['AveragePrice'].drop(['AveragePrice']).plot(kind='bar',color = 'c')
plt.xlabel('Features',fontsize=15)
plt.ylabel('AveragePrice',fontsize=15)
plt.title('Correlation of features with Target Variable Average Price',fontsize = 18)
plt.show()

# %% [markdown]
# # Skewness of features

# %%
df3.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type           -2.821090
# Year            0.027740
# Month           0.233418
# Day             1.828332
# dtype: float64

# %% [markdown]
# # Standard Scaling

# %%
X = df3.drop('AveragePrice', axis=1)
Y = df3['AveragePrice']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso
from xgboost import XGBRegressor

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=42, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (11033, 9)
# Training target vector size: (11033,)
# Test feature matrix size: (5435, 9)
# Test target vector size: (5435,)
